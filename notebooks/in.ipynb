# %%
from jose import jwt
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\yuvra\OneDrive\Desktop\Weather-Forecasting-Project\venv\Lib\site-packages\IPython\core\interactiveshell.py:3701 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 1
#     from jose import jwt
#
#   File c:\Users\yuvra\OneDrive\Desktop\Weather-Forecasting-Project\venv\Lib\site-packages\jose.py:546
#     print decrypt(deserialize_compact(jwt), {'k':key},
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
df = pd.read_csv(r"C:\Users\yuvra\OneDrive\Desktop\Weather-Forecasting-Project\data\weather_kaggle.csv")
